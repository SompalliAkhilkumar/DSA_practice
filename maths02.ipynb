# %% [markdown]
# <a href="https://colab.research.google.com/github/SompalliAkhilkumar/DSA_practice/blob/main/maths02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
c = 0
while(n>0):
    d = n%10
    c = c + 1
    n = n//10
print(c)
# Out:
#  123456789
# 9

# %%
n = str(input())
c = 0
for i in n:
    c = c + 1
print(c)
# Out:
#  23451
# 5

# %%
n = int(input())
r = 0
while(n>0):
    d = n % 10
    r = (r*10) + d
    n = n//10
print(r)
# Out:
#  234
# 432

# %%
n = str(input())
r = 0
for i in n:
    r = (r/10) + int(i)
z = int(len(n))-1
print(int(r*(10**z)))
# Out:
#  123
# 321

# %%
n = int(input())
a = n
r = 0
while(n>0):
    d = n % 10
    r = (r*10)+d
    n = n // 10
print(a==r)
# Out:
#  121
# True

# %%
n = int(input())
b = n
a = 0
while(n>0):
    d = n % 10
    a = a + (d**3)
    n = n // 10
print(a==b)
# Out:
#  111
# False

# %%
n = int(input())
for i in range(1,n+1):
    if(n%i == 0):
        print(i)
# Out:
#  10
# 1
# 2
# 5
# 10

# %%
import math

s = int(input())
n = int(math.sqrt(s))
for i in range(1,n+1):
    if(s%i == 0):
        print(i)
        if(s/i != i):
            print(int(s/i))
# Out:
#  10
# 1
# 10
# 2
# 5

# %%
    import math

    number = 10
    square_root = math.sqrt(number)
    print(square_root)
# Out:
# 3.1622776601683795

# %%
n = int(input())
for i in range(1,n+1):
    if(n%i == 0):
        print(i)
# Out:
#  5
# 1
# 5

# %%
n = int(input())
c = 0
for i in range(1,n+1):
    if(n%i == 0):
        c = c + 1
print(c == 2)
# Out:
#  5
# True

# %%
import math
n = int(input())
s = int(math.sqrt(n))
c = 0
for i in range(1,s+1):
    if(n%i == 0):
        c = c + 1
        if (n // i) != i:
            c = c + 1
print(c == 2)
# Out:
#  21
# False

# %%
a = int(input())
b = int(input())
n = min(a,b)
gcd = 0
for i in range(1,n+1):
    if (a%i == 0) and (b%i == 0):
        gcd = i
print(gcd)
# Out:
#  20
#  40
# 20

# %%
a = int(input())
b = int(input())
n = min(a,b)
gcd = 0
for i in range(n+1,1,-1):
    if (a%i == 0) and (b%i == 0):
        gcd = i
        break
print(gcd)
# Out:
#  20
#  40
# 20

# %%
a = int(input())
b = int(input())
gcd = 0
while (a > 0) and (b > 0):
    if (a > b):
        a = a % b
    else:
        b = b % a
if (a == 0):
    print(b)
else:
    print(a)
# Out:
#  2
#  4
# 2
